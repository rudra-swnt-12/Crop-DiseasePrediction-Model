# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %matplotlib inline

# %%
df = pd.read_csv('/Users/rudrasawant/Downloads/Disease Prediction/data/yield.csv')
df.head()
# Out:
#   District        Block  No of samples  Acidic (%)  Neutral (%)  Alkaline (%)  \
# 0    Angul        Angul            150          51           21            29
# 1    Angul     Athmalik            130          47           31            22
# 2    Angul     Banarpal             90          30           26            44
# 3    Angul  Chhendipada            100          60           22            18
# 4    Angul       Kaniha            150          93            1             5
#
#    Normal EC (%)  OC (%)  P (%)  K (%)  Ca (%)  Mg (%)  S (%)  Zn (%)  B (%)  \
# 0            100      42     45      7       0      11     46      62     76
# 1            100      37     42      9       5      24     28      55     70
# 2            100      39     39      0       1       9     13      56     73
# 3            100      33     43     13       9      34     24      82     70
# 4            100      34     49     25      11      35     33      76     80
#
#    Fe (%)  Cu (%)  Mn (%)  Yield (kg/ha)
# 0       3       0       7           2634
# 1       2       0       2           2446
# 2       3       1      16           2429
# 3      11       7      23           2587
# 4       1       2      17           2641

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   District       310 non-null    object
#  1   Block          310 non-null    object
#  2   No of samples  310 non-null    int64
#  3   Acidic (%)     310 non-null    int64
#  4   Neutral (%)    310 non-null    int64
#  5   Alkaline (%)   310 non-null    int64
#  6   Normal EC (%)  310 non-null    int64
#  7   OC (%)         310 non-null    int64
#  8   P (%)          310 non-null    int64
#  9   K (%)          310 non-null    int64
#  10  Ca (%)         310 non-null    int64
#  11  Mg (%)         310 non-null    int64
#  12  S (%)          310 non-null    int64
#  13  Zn (%)         310 non-null    int64
#  14  B (%)          310 non-null    int64
#  15  Fe (%)         310 non-null    int64
#  16  Cu (%)         310 non-null    int64
#  17  Mn (%)         310 non-null    int64
#  18  Yield (kg/ha)  310 non-null    int64
# dtypes: int64(17), object(2)
# memory usage: 46.1+ KB

# %%
# Numerical Features
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'object']
print("Numerical Features: ", len(numerical_features))

# Categorical Features
categorical_features = [feature for feature in df.columns if df[feature].dtypes == 'object']
print("Categorical Features: ", len(categorical_features))

# Discrete Features
discrete_features = [feature for feature in numerical_features if len(df[feature].unique()) <= 25]
print("Discrete Features: ", len(discrete_features))

# Continuous Features
continuous_features = [feature for feature in numerical_features if feature not in discrete_features]
print("Continuous Features: ", len(continuous_features))
# Out:
# Numerical Features:  17
# Categorical Features:  2
# Discrete Features:  4
# Continuous Features:  13

# %%
df.columns = df.columns.str.strip()

# %%
# Independent & Dependent Features
X = df.drop(columns=['Yield (kg/ha)'])
Y = df['Yield (kg/ha)']

# %%
X.head()
# Out:
#   District        Block  No of samples  Acidic (%)  Neutral (%)  Alkaline (%)  \
# 0    Angul        Angul            150          51           21            29
# 1    Angul     Athmalik            130          47           31            22
# 2    Angul     Banarpal             90          30           26            44
# 3    Angul  Chhendipada            100          60           22            18
# 4    Angul       Kaniha            150          93            1             5
#
#    Normal EC (%)  OC (%)  P (%)  K (%)  Ca (%)  Mg (%)  S (%)  Zn (%)  B (%)  \
# 0            100      42     45      7       0      11     46      62     76
# 1            100      37     42      9       5      24     28      55     70
# 2            100      39     39      0       1       9     13      56     73
# 3            100      33     43     13       9      34     24      82     70
# 4            100      34     49     25      11      35     33      76     80
#
#    Fe (%)  Cu (%)  Mn (%)
# 0       3       0       7
# 1       2       0       2
# 2       3       1      16
# 3      11       7      23
# 4       1       2      17

# %%
Y.head()
# Out:
# 0    2634
# 1    2446
# 2    2429
# 3    2587
# 4    2641
# Name: Yield (kg/ha), dtype: int64

# %%
# Applying Label Encoding to Categorical Features
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
X['District'] = label_encoder.fit_transform(X['District'])
X['Block'] = label_encoder.fit_transform(X['Block'])

# Create a ColumnTransformer for One-Hot Encoding
numerical_features = X.select_dtypes(exclude=['object']).columns
categorical_features = X.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(
    [
        ('OneHotEncoder', OneHotEncoder(), categorical_features),
        ('StandardScaler', StandardScaler(), numerical_features)
    ], remainder='passthrough'
)

# %%
# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Scaling the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Model Training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

import datetime

# %%
model = Sequential([
    # Input Layer connected to the first hidden layer
    # Starts with a reasonable number of neurons (e.g., 128)
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    # Add a Dropout layer to prevent overfitting
    Dropout(0.3),

    # Second hidden layer to learn more complex patterns
    Dense(64, activation='relu'),
    # Add another Dropout layer
    Dropout(0.3),

    # Output layer for binary classification
    Dense(1, activation="linear")
])
# Out:
# /opt/anaconda3/envs/disease_pred/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_37 (Dense)                │ (None, 128)            │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,753 (42.00 KB)
#  Trainable params: 10,753 (42.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
loss = tf.keras.losses.MeanSquaredError()
model.compile(optimizer=optimizer, loss=loss, metrics=['mean_squared_error'])
metrics = ["mae", "mse"]

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorflow_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
early_stopping_callback = EarlyStopping(
    monitor='val_loss', # Monitor validation loss for early stopping
    patience=20, # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity
)

# %%
history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_test, Y_test),
    epochs=150,
    callbacks=[tensorflow_callback, early_stopping_callback]
)
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8625591.0000 - mean_squared_error: 8625591.0000 - val_loss: 8329832.5000 - val_mean_squared_error: 8329833.0000
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8438273.0000 - mean_squared_error: 8438273.0000 - val_loss: 7987261.0000 - val_mean_squared_error: 7987261.0000
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7911069.0000 - mean_squared_error: 7911069.0000 - val_loss: 7161958.5000 - val_mean_squared_error: 7161958.5000
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6807951.5000 - mean_squared_error: 6807951.5000 - val_loss: 5601734.0000 - val_mean_squared_error: 5601734.0000
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4842077.5000 - mean_squared_error: 4842077.5000 - val_loss: 3322232.7500 - val_mean_squared_error: 3322232.7500
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2468394.7500 - mean_squared_error: 2468394.7500 - val_loss: 1204199.0000 - val_mean_squared_error: 1204199.0000
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 886669.8125 - mean_squared_error: 886669.8125 - val_loss: 668571.3750 - val_mean_squared_error: 668571.3750
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 739971.7500 - mean_squared_error: 739971.7500 - val_loss: 637440.6875 - val_mean_squared_error: 637440.6875
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 640873.2500 - mean_squared_error: 640873.2500 - val_loss: 357453.2500 - val_mean_squared_error: 357453.2500
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 471923.8750 - mean_squared_error: 471923.8750 - val_loss: 319467.7500 - val_mean_squared_error: 319467.7500
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 418735.5938 - mean_squared_error: 418735.5938 - val_loss: 289383.5625 - val_mean_squared_error: 289383.5625
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 362984.3125 - mean_squared_error: 362984.3125 - val_loss: 260935.1875 - val_mean_squared_error: 260935.1875
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 321775.7188 - mean_squared_error: 321775.7188 - val_loss: 258062.7812 - val_mean_squared_error: 258062.7812
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 359443.6250 - mean_squared_error: 359443.6250 - val_loss: 245608.1875 - val_mean_squared_error: 245608.1875
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 421964.8125 - mean_squared_error: 421964.8125 - val_loss: 230160.1875 - val_mean_squared_error: 230160.1875
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 336925.3125 - mean_squared_error: 336925.3125 - val_loss: 220458.6562 - val_mean_squared_error: 220458.6562
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 313979.6875 - mean_squared_error: 313979.6875 - val_loss: 200538.5000 - val_mean_squared_error: 200538.5000
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 331991.9375 - mean_squared_error: 331991.9375 - val_loss: 185430.2812 - val_mean_squared_error: 185430.2812
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 287455.1250 - mean_squared_error: 287455.1250 - val_loss: 185614.7812 - val_mean_squared_error: 185614.7812
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 302733.5312 - mean_squared_error: 302733.5312 - val_loss: 190156.7031 - val_mean_squared_error: 190156.7031
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 250120.9375 - mean_squared_error: 250120.9375 - val_loss: 190222.6094 - val_mean_squared_error: 190222.6094
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 272094.3125 - mean_squared_error: 272094.3125 - val_loss: 177006.4219 - val_mean_squared_error: 177006.4219
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 244902.6250 - mean_squared_error: 244902.6250 - val_loss: 165262.9688 - val_mean_squared_error: 165262.9688
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 291144.9688 - mean_squared_error: 291144.9688 - val_loss: 166326.6875 - val_mean_squared_error: 166326.6875
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 233449.5156 - mean_squared_error: 233449.5156 - val_loss: 162890.1562 - val_mean_squared_error: 162890.1562
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 262411.6250 - mean_squared_error: 262411.6250 - val_loss: 158357.0938 - val_mean_squared_error: 158357.0938
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 273065.1875 - mean_squared_error: 273065.1875 - val_loss: 166672.5156 - val_mean_squared_error: 166672.5156
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 229738.3750 - mean_squared_error: 229738.3750 - val_loss: 167351.8438 - val_mean_squared_error: 167351.8438
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 220179.0000 - mean_squared_error: 220179.0000 - val_loss: 154417.0938 - val_mean_squared_error: 154417.0938
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 238685.0625 - mean_squared_error: 238685.0625 - val_loss: 145134.3594 - val_mean_squared_error: 145134.3594
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 199790.4219 - mean_squared_error: 199790.4219 - val_loss: 143372.0312 - val_mean_squared_error: 143372.0312
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 217017.0156 - mean_squared_error: 217017.0156 - val_loss: 135768.4531 - val_mean_squared_error: 135768.4531
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 254717.4219 - mean_squared_error: 254717.4219 - val_loss: 123017.8125 - val_mean_squared_error: 123017.8125
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 230009.3906 - mean_squared_error: 230009.3906 - val_loss: 118569.1641 - val_mean_squared_error: 118569.1641
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183385.5156 - mean_squared_error: 183385.5156 - val_loss: 130669.8828 - val_mean_squared_error: 130669.8828
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 233734.5156 - mean_squared_error: 233734.5156 - val_loss: 124968.7578 - val_mean_squared_error: 124968.7578
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 192734.3125 - mean_squared_error: 192734.3125 - val_loss: 128222.9219 - val_mean_squared_error: 128222.9219
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 228430.0625 - mean_squared_error: 228430.0625 - val_loss: 127900.1641 - val_mean_squared_error: 127900.1641
# Epoch 39/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 228510.2969 - mean_squared_error: 228510.2969 - val_loss: 114713.0469 - val_mean_squared_error: 114713.0469
# Epoch 40/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 206657.6875 - mean_squared_error: 206657.6875 - val_loss: 105674.7734 - val_mean_squared_error: 105674.7734
# Epoch 41/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 176289.8438 - mean_squared_error: 176289.8438 - val_loss: 111227.0703 - val_mean_squared_error: 111227.0703
# Epoch 42/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173678.9688 - mean_squared_error: 173678.9688 - val_loss: 127180.4688 - val_mean_squared_error: 127180.4688
# Epoch 43/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 199856.0156 - mean_squared_error: 199856.0156 - val_loss: 126233.0000 - val_mean_squared_error: 126233.0000
# Epoch 44/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 189278.9219 - mean_squared_error: 189278.9219 - val_loss: 110247.1641 - val_mean_squared_error: 110247.1641
# Epoch 45/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 182550.7031 - mean_squared_error: 182550.7031 - val_loss: 101861.6484 - val_mean_squared_error: 101861.6484
# Epoch 46/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 202151.6094 - mean_squared_error: 202151.6094 - val_loss: 93277.5000 - val_mean_squared_error: 93277.5078
# Epoch 47/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 170485.1094 - mean_squared_error: 170485.1094 - val_loss: 92987.5078 - val_mean_squared_error: 92987.5078
# Epoch 48/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 177856.9375 - mean_squared_error: 177856.9375 - val_loss: 96115.2891 - val_mean_squared_error: 96115.2891
# Epoch 49/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 227780.8125 - mean_squared_error: 227780.8125 - val_loss: 99258.7734 - val_mean_squared_error: 99258.7734
# Epoch 50/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 180771.5312 - mean_squared_error: 180771.5312 - val_loss: 96046.0312 - val_mean_squared_error: 96046.0312
# Epoch 51/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 202810.4531 - mean_squared_error: 202810.4531 - val_loss: 89256.7891 - val_mean_squared_error: 89256.7891
# Epoch 52/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 167522.2969 - mean_squared_error: 167522.2969 - val_loss: 87159.0547 - val_mean_squared_error: 87159.0547
# Epoch 53/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 192179.5469 - mean_squared_error: 192179.5469 - val_loss: 81156.4531 - val_mean_squared_error: 81156.4531
# Epoch 54/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 174963.0938 - mean_squared_error: 174963.0938 - val_loss: 81786.9844 - val_mean_squared_error: 81786.9844
# Epoch 55/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 169940.8438 - mean_squared_error: 169940.8438 - val_loss: 80408.4688 - val_mean_squared_error: 80408.4688
# Epoch 56/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 186259.9531 - mean_squared_error: 186259.9531 - val_loss: 81261.7422 - val_mean_squared_error: 81261.7422
# Epoch 57/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 179103.7188 - mean_squared_error: 179103.7188 - val_loss: 83717.5625 - val_mean_squared_error: 83717.5625
# Epoch 58/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 213699.0156 - mean_squared_error: 213699.0156 - val_loss: 82622.1641 - val_mean_squared_error: 82622.1641
# Epoch 59/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190313.6406 - mean_squared_error: 190313.6406 - val_loss: 86628.5781 - val_mean_squared_error: 86628.5781
# Epoch 60/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 204578.1875 - mean_squared_error: 204578.1875 - val_loss: 85250.7031 - val_mean_squared_error: 85250.7031
# Epoch 61/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183799.9219 - mean_squared_error: 183799.9219 - val_loss: 87591.5391 - val_mean_squared_error: 87591.5391
# Epoch 62/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173806.4844 - mean_squared_error: 173806.4844 - val_loss: 84020.4844 - val_mean_squared_error: 84020.4844
# Epoch 63/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 154203.4688 - mean_squared_error: 154203.4688 - val_loss: 75049.8125 - val_mean_squared_error: 75049.8125
# Epoch 64/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 219357.5781 - mean_squared_error: 219357.5781 - val_loss: 73223.1719 - val_mean_squared_error: 73223.1719
# Epoch 65/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 192474.1719 - mean_squared_error: 192474.1719 - val_loss: 92615.6719 - val_mean_squared_error: 92615.6719
# Epoch 66/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 182461.1406 - mean_squared_error: 182461.1406 - val_loss: 94740.4219 - val_mean_squared_error: 94740.4219
# Epoch 67/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 178199.2812 - mean_squared_error: 178199.2812 - val_loss: 80804.1719 - val_mean_squared_error: 80804.1719
# Epoch 68/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 220668.9844 - mean_squared_error: 220668.9844 - val_loss: 71423.5312 - val_mean_squared_error: 71423.5312
# Epoch 69/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173693.3438 - mean_squared_error: 173693.3438 - val_loss: 60425.8711 - val_mean_squared_error: 60425.8711
# Epoch 70/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183912.1875 - mean_squared_error: 183912.1875 - val_loss: 66557.2109 - val_mean_squared_error: 66557.2109
# Epoch 71/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 197168.3438 - mean_squared_error: 197168.3438 - val_loss: 69823.7188 - val_mean_squared_error: 69823.7188
# Epoch 72/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173459.6875 - mean_squared_error: 173459.6875 - val_loss: 66543.1875 - val_mean_squared_error: 66543.1875
# Epoch 73/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 164914.1250 - mean_squared_error: 164914.1250 - val_loss: 67107.7266 - val_mean_squared_error: 67107.7266
# Epoch 74/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 170625.0781 - mean_squared_error: 170625.0781 - val_loss: 66590.8516 - val_mean_squared_error: 66590.8516
# Epoch 75/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 204935.1719 - mean_squared_error: 204935.1719 - val_loss: 68506.5391 - val_mean_squared_error: 68506.5391
# Epoch 76/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185755.0781 - mean_squared_error: 185755.0781 - val_loss: 61233.9258 - val_mean_squared_error: 61233.9258
# Epoch 77/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 157398.9062 - mean_squared_error: 157398.9062 - val_loss: 70591.3047 - val_mean_squared_error: 70591.3047
# Epoch 78/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 186940.6719 - mean_squared_error: 186940.6719 - val_loss: 64168.5156 - val_mean_squared_error: 64168.5156
# Epoch 79/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 182818.4688 - mean_squared_error: 182818.4688 - val_loss: 60911.3633 - val_mean_squared_error: 60911.3633
# Epoch 80/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 195802.2344 - mean_squared_error: 195802.2344 - val_loss: 60973.7422 - val_mean_squared_error: 60973.7422
# Epoch 81/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 179776.6406 - mean_squared_error: 179776.6406 - val_loss: 59216.1758 - val_mean_squared_error: 59216.1758
# Epoch 82/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 182114.1094 - mean_squared_error: 182114.1094 - val_loss: 46286.6445 - val_mean_squared_error: 46286.6445
# Epoch 83/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 191984.7812 - mean_squared_error: 191984.7812 - val_loss: 53158.6328 - val_mean_squared_error: 53158.6328
# Epoch 84/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 207837.5156 - mean_squared_error: 207837.5156 - val_loss: 57006.6758 - val_mean_squared_error: 57006.6758
# Epoch 85/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 175399.1094 - mean_squared_error: 175399.1094 - val_loss: 62867.0781 - val_mean_squared_error: 62867.0781
# Epoch 86/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 200993.9531 - mean_squared_error: 200993.9531 - val_loss: 60216.0000 - val_mean_squared_error: 60216.0000
# Epoch 87/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 189940.6719 - mean_squared_error: 189940.6719 - val_loss: 58441.4609 - val_mean_squared_error: 58441.4609
# Epoch 88/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 231880.0938 - mean_squared_error: 231880.0938 - val_loss: 63123.5664 - val_mean_squared_error: 63123.5664
# Epoch 89/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190986.7031 - mean_squared_error: 190986.7031 - val_loss: 58583.6719 - val_mean_squared_error: 58583.6719
# Epoch 90/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185132.8125 - mean_squared_error: 185132.8125 - val_loss: 64457.7188 - val_mean_squared_error: 64457.7188
# Epoch 91/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 202391.5938 - mean_squared_error: 202391.5938 - val_loss: 48049.9727 - val_mean_squared_error: 48049.9727
# Epoch 92/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 161036.0000 - mean_squared_error: 161036.0000 - val_loss: 50801.1758 - val_mean_squared_error: 50801.1758
# Epoch 93/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 172864.1094 - mean_squared_error: 172864.1094 - val_loss: 46288.0586 - val_mean_squared_error: 46288.0586
# Epoch 94/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 176340.1406 - mean_squared_error: 176340.1406 - val_loss: 51461.1641 - val_mean_squared_error: 51461.1641
# Epoch 95/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 221038.7344 - mean_squared_error: 221038.7344 - val_loss: 49778.3594 - val_mean_squared_error: 49778.3594
# Epoch 96/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185091.4531 - mean_squared_error: 185091.4531 - val_loss: 49297.5820 - val_mean_squared_error: 49297.5820
# Epoch 97/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 191510.1562 - mean_squared_error: 191510.1562 - val_loss: 46278.8633 - val_mean_squared_error: 46278.8633
# Epoch 98/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 174696.2969 - mean_squared_error: 174696.2969 - val_loss: 41680.0977 - val_mean_squared_error: 41680.0977
# Epoch 99/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 159578.2656 - mean_squared_error: 159578.2656 - val_loss: 54554.8047 - val_mean_squared_error: 54554.8047
# Epoch 100/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 186813.9375 - mean_squared_error: 186813.9375 - val_loss: 48810.8477 - val_mean_squared_error: 48810.8477
# Epoch 101/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 170884.7031 - mean_squared_error: 170884.7031 - val_loss: 41785.9102 - val_mean_squared_error: 41785.9102
# Epoch 102/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 199480.6094 - mean_squared_error: 199480.6094 - val_loss: 40979.7031 - val_mean_squared_error: 40979.7031
# Epoch 103/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 216564.8125 - mean_squared_error: 216564.8125 - val_loss: 43861.4766 - val_mean_squared_error: 43861.4766
# Epoch 104/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 169577.0625 - mean_squared_error: 169577.0625 - val_loss: 44283.5508 - val_mean_squared_error: 44283.5508
# Epoch 105/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 160779.0156 - mean_squared_error: 160779.0156 - val_loss: 41691.1250 - val_mean_squared_error: 41691.1250
# Epoch 106/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 194540.8750 - mean_squared_error: 194540.8750 - val_loss: 45307.9492 - val_mean_squared_error: 45307.9492
# Epoch 107/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 181918.7812 - mean_squared_error: 181918.7812 - val_loss: 47702.7812 - val_mean_squared_error: 47702.7812
# Epoch 108/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 194156.3438 - mean_squared_error: 194156.3438 - val_loss: 59807.1992 - val_mean_squared_error: 59807.1992
# Epoch 109/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 163598.7031 - mean_squared_error: 163598.7031 - val_loss: 35531.0352 - val_mean_squared_error: 35531.0352
# Epoch 110/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 166011.2344 - mean_squared_error: 166011.2344 - val_loss: 42976.0234 - val_mean_squared_error: 42976.0234
# Epoch 111/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 143220.4062 - mean_squared_error: 143220.4062 - val_loss: 35857.6055 - val_mean_squared_error: 35857.6055
# Epoch 112/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 176560.1875 - mean_squared_error: 176560.1875 - val_loss: 37894.5195 - val_mean_squared_error: 37894.5195
# Epoch 113/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 167799.4062 - mean_squared_error: 167799.4062 - val_loss: 38234.5859 - val_mean_squared_error: 38234.5859
# Epoch 114/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 198360.6406 - mean_squared_error: 198360.6406 - val_loss: 34974.8594 - val_mean_squared_error: 34974.8594
# Epoch 115/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 148657.9219 - mean_squared_error: 148657.9219 - val_loss: 44044.6836 - val_mean_squared_error: 44044.6836
# Epoch 116/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183091.0938 - mean_squared_error: 183091.0938 - val_loss: 41940.9062 - val_mean_squared_error: 41940.9062
# Epoch 117/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 152915.9375 - mean_squared_error: 152915.9375 - val_loss: 39566.5859 - val_mean_squared_error: 39566.5859
# Epoch 118/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 187715.9844 - mean_squared_error: 187715.9844 - val_loss: 36542.2422 - val_mean_squared_error: 36542.2422
# Epoch 119/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 196774.9375 - mean_squared_error: 196774.9375 - val_loss: 36933.1602 - val_mean_squared_error: 36933.1602
# Epoch 120/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 159567.2812 - mean_squared_error: 159567.2812 - val_loss: 38477.1797 - val_mean_squared_error: 38477.1797
# Epoch 121/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 170233.3750 - mean_squared_error: 170233.3750 - val_loss: 35211.0312 - val_mean_squared_error: 35211.0312
# Epoch 122/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185975.1562 - mean_squared_error: 185975.1562 - val_loss: 34450.2031 - val_mean_squared_error: 34450.2031
# Epoch 123/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 168928.2031 - mean_squared_error: 168928.2031 - val_loss: 39236.4961 - val_mean_squared_error: 39236.4961
# Epoch 124/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 155458.7188 - mean_squared_error: 155458.7188 - val_loss: 44195.6719 - val_mean_squared_error: 44195.6719
# Epoch 125/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 153774.6562 - mean_squared_error: 153774.6562 - val_loss: 35606.2422 - val_mean_squared_error: 35606.2422
# Epoch 126/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 179246.4219 - mean_squared_error: 179246.4219 - val_loss: 34109.2344 - val_mean_squared_error: 34109.2344
# Epoch 127/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 164465.1562 - mean_squared_error: 164465.1562 - val_loss: 34311.9922 - val_mean_squared_error: 34311.9922
# Epoch 128/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 163155.0781 - mean_squared_error: 163155.0781 - val_loss: 33136.2344 - val_mean_squared_error: 33136.2344
# Epoch 129/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 190002.3281 - mean_squared_error: 190002.3281 - val_loss: 32010.6523 - val_mean_squared_error: 32010.6523
# Epoch 130/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 162490.7969 - mean_squared_error: 162490.7969 - val_loss: 29658.5430 - val_mean_squared_error: 29658.5430
# Epoch 131/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185812.2344 - mean_squared_error: 185812.2344 - val_loss: 35377.5352 - val_mean_squared_error: 35377.5352
# Epoch 132/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 160059.2188 - mean_squared_error: 160059.2188 - val_loss: 30605.4121 - val_mean_squared_error: 30605.4121
# Epoch 133/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 168302.2969 - mean_squared_error: 168302.2969 - val_loss: 30841.7773 - val_mean_squared_error: 30841.7773
# Epoch 134/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 151834.8594 - mean_squared_error: 151834.8594 - val_loss: 38263.5117 - val_mean_squared_error: 38263.5117
# Epoch 135/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 185929.5000 - mean_squared_error: 185929.5000 - val_loss: 34054.5234 - val_mean_squared_error: 34054.5234
# Epoch 136/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 142752.4531 - mean_squared_error: 142752.4531 - val_loss: 39074.1484 - val_mean_squared_error: 39074.1484
# Epoch 137/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 181296.3438 - mean_squared_error: 181296.3438 - val_loss: 37328.1211 - val_mean_squared_error: 37328.1211
# Epoch 138/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 164825.6250 - mean_squared_error: 164825.6250 - val_loss: 26694.1543 - val_mean_squared_error: 26694.1543
# Epoch 139/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 132144.8125 - mean_squared_error: 132144.8125 - val_loss: 30112.2402 - val_mean_squared_error: 30112.2402
# Epoch 140/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 169679.8594 - mean_squared_error: 169679.8594 - val_loss: 39655.0742 - val_mean_squared_error: 39655.0742
# Epoch 141/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 160383.9062 - mean_squared_error: 160383.9062 - val_loss: 39834.3164 - val_mean_squared_error: 39834.3164
# Epoch 142/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 179876.4844 - mean_squared_error: 179876.4844 - val_loss: 34105.9883 - val_mean_squared_error: 34105.9883
# Epoch 143/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 162958.8750 - mean_squared_error: 162958.8750 - val_loss: 34702.8789 - val_mean_squared_error: 34702.8789
# Epoch 144/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 154728.5312 - mean_squared_error: 154728.5312 - val_loss: 32042.9121 - val_mean_squared_error: 32042.9121
# Epoch 145/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 158898.2969 - mean_squared_error: 158898.2969 - val_loss: 43037.2031 - val_mean_squared_error: 43037.2031
# Epoch 146/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 205660.6719 - mean_squared_error: 205660.6719 - val_loss: 49083.2773 - val_mean_squared_error: 49083.2773
# Epoch 147/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 208355.4062 - mean_squared_error: 208355.4062 - val_loss: 36236.9336 - val_mean_squared_error: 36236.9336
# Epoch 148/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 168219.9062 - mean_squared_error: 168219.9062 - val_loss: 33611.9805 - val_mean_squared_error: 33611.9805
# Epoch 149/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 172548.5000 - mean_squared_error: 172548.5000 - val_loss: 27740.3379 - val_mean_squared_error: 27740.3379
# Epoch 150/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 178113.7031 - mean_squared_error: 178113.7031 - val_loss: 21753.4180 - val_mean_squared_error: 21753.4180

# %%
model.save('/Users/rudrasawant/Downloads/Disease Prediction/models/historical_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
