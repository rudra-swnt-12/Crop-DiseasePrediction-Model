# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

# Define global parameters
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# %%
import os

dir_to_find = "tomato_dataset"
found_path = None

# Search for the directory starting from one level up '..'
# This is often needed if your notebook is in a subfolder like 'notebooks/'
for root, dirs, files in os.walk('..'):
    if dir_to_find in dirs:
        found_path = os.path.join(root, dir_to_find)
        break

if found_path:
    print(f"✅ Directory found! Use this path:\n{found_path}")
else:
    print(f"❌ Directory not found. Please check your folder structure.")
# Out:
# ✅ Directory found! Use this path:
# ../data/tomato_dataset

# %% [markdown]
# ### Tomato Model

# %%
TOMATO_TRAIN_DIR = "../data/tomato_dataset/train/"
TOMATO_VAL_DIR = "../data/tomato_dataset/validation/"

tomato_train_ds = tf.keras.utils.image_dataset_from_directory(
    TOMATO_TRAIN_DIR,
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

tomato_val_ds = tf.keras.utils.image_dataset_from_directory(
    TOMATO_VAL_DIR,
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

tomato_class_names = tomato_train_ds.class_names
print("Classes:", tomato_class_names)

base_model_tomato = tf.keras.applications.MobileNetV3Small(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
base_model_tomato.trainable = False

inputs_tomato = keras.Input(shape=(224, 224, 3))
x = tf.keras.applications.mobilenet_v3.preprocess_input(inputs_tomato)
x = base_model_tomato(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
outputs_tomato = layers.Dense(len(tomato_class_names), activation='softmax')(x)
tomato_model = keras.Model(inputs_tomato, outputs_tomato)

# Compile with initial learning rate
initial_learning_rate = 0.001
tomato_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Early stopping callback
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# Learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

# Train with callbacks
print("\n--- Training the Tomato Disease Model ---")
history_tomato = tomato_model.fit(
    tomato_train_ds,
    validation_data=tomato_val_ds,
    epochs=100,
    callbacks=[early_stopping, lr_scheduler]
)

# Save model
tomato_model.save("/Users/rudrasawant/Downloads/Disease Prediction/models/tomato_disease_model.h5")
print("\n✅ Tomato model saved successfully!")
# Out:
# Found 4 files belonging to 2 classes.
# Found 4 files belonging to 2 classes.
# Classes: ['Healthy', 'Late_Blight']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 3s 1us/step
#
# --- Training the Tomato Disease Model ---
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5000 - loss: 1.5274 - val_accuracy: 0.5000 - val_loss: 1.3791 - learning_rate: 0.0010
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5000 - loss: 1.3791 - val_accuracy: 0.5000 - val_loss: 1.2367 - learning_rate: 0.0010
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5000 - loss: 1.2367 - val_accuracy: 0.5000 - val_loss: 1.1017 - learning_rate: 0.0010
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5000 - loss: 1.1017 - val_accuracy: 0.5000 - val_loss: 0.9755 - learning_rate: 0.0010
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5000 - loss: 0.9755 - val_accuracy: 0.5000 - val_loss: 0.8594 - learning_rate: 0.0010
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5000 - loss: 0.8594 - val_accuracy: 0.7500 - val_loss: 0.7539 - learning_rate: 0.0010
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - loss: 0.7539 - val_accuracy: 0.7500 - val_loss: 0.6593 - learning_rate: 0.0010
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - loss: 0.6593 - val_accuracy: 0.7500 - val_loss: 0.5753 - learning_rate: 0.0010
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 0.5753 - val_accuracy: 0.7500 - val_loss: 0.5012 - learning_rate: 0.0010
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - loss: 0.5012 - val_accuracy: 0.7500 - val_loss: 0.4361 - learning_rate: 0.0010
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.4361 - val_accuracy: 0.7500 - val_loss: 0.3792 - learning_rate: 0.0010
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.3792 - val_accuracy: 0.7500 - val_loss: 0.3297 - learning_rate: 0.0010
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - loss: 0.3297 - val_accuracy: 1.0000 - val_loss: 0.2867 - learning_rate: 0.0010
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2867 - val_accuracy: 1.0000 - val_loss: 0.2495 - learning_rate: 0.0010
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2495 - val_accuracy: 1.0000 - val_loss: 0.2174 - learning_rate: 0.0010
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2174 - val_accuracy: 1.0000 - val_loss: 0.1898 - learning_rate: 0.0010
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.1898 - val_accuracy: 1.0000 - val_loss: 0.1661 - learning_rate: 0.0010
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.1661 - val_accuracy: 1.0000 - val_loss: 0.1458 - learning_rate: 0.0010
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.1458 - val_accuracy: 1.0000 - val_loss: 0.1285 - learning_rate: 0.0010
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.1137 - learning_rate: 0.0010
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.1137 - val_accuracy: 1.0000 - val_loss: 0.1011 - learning_rate: 0.0010
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.1011 - val_accuracy: 1.0000 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0903 - val_accuracy: 1.0000 - val_loss: 0.0811 - learning_rate: 0.0010
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0811 - val_accuracy: 1.0000 - val_loss: 0.0731 - learning_rate: 0.0010
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0731 - val_accuracy: 1.0000 - val_loss: 0.0663 - learning_rate: 0.0010
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0663 - val_accuracy: 1.0000 - val_loss: 0.0604 - learning_rate: 0.0010
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0604 - val_accuracy: 1.0000 - val_loss: 0.0553 - learning_rate: 0.0010
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0553 - val_accuracy: 1.0000 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0508 - val_accuracy: 1.0000 - val_loss: 0.0470 - learning_rate: 0.0010
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0470 - val_accuracy: 1.0000 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 1.0000 - val_loss: 0.0406 - learning_rate: 0.0010
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0379 - learning_rate: 0.0010
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 1.0000 - val_loss: 0.0356 - learning_rate: 0.0010
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0356 - val_accuracy: 1.0000 - val_loss: 0.0335 - learning_rate: 0.0010
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0335 - val_accuracy: 1.0000 - val_loss: 0.0317 - learning_rate: 0.0010
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0285 - learning_rate: 0.0010
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0260 - learning_rate: 0.0010
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0229 - learning_rate: 0.0010
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 0.0206 - learning_rate: 0.0010
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0193 - learning_rate: 0.0010
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0188 - learning_rate: 0.0010
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0182 - learning_rate: 0.0010
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 0.0177 - learning_rate: 0.0010
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0173 - learning_rate: 0.0010
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 1.0000 - val_loss: 0.0168 - learning_rate: 0.0010
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0150 - learning_rate: 0.0010
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0147 - learning_rate: 0.0010
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0134 - learning_rate: 0.0010
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0129 - learning_rate: 0.0010
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0121 - learning_rate: 0.0010
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 0.0010
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0083 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 100.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Tomato model saved successfully!

# %%
RICE_TRAIN_DIR = "../data/rice_dataset/train/"
RICE_VAL_DIR = "../data/rice_dataset/validation/"

rice_train_ds = tf.keras.utils.image_dataset_from_directory(
    RICE_TRAIN_DIR,
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

rice_val_ds = tf.keras.utils.image_dataset_from_directory(
    RICE_VAL_DIR,
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

rice_class_names = rice_train_ds.class_names
print("Rice classes:", rice_class_names)


tomato_val_ds = tf.keras.utils.image_dataset_from_directory(
    TOMATO_VAL_DIR,
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

tomato_class_names = tomato_train_ds.class_names
print("Classes:", tomato_class_names)

# 2. Build the model architecture
base_model_rice = tf.keras.applications.MobileNetV3Small(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
base_model_rice.trainable = False

inputs_rice = keras.Input(shape=(224, 224, 3))
x = tf.keras.applications.mobilenet_v3.preprocess_input(inputs_rice)
x = base_model_rice(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
outputs_rice = layers.Dense(len(rice_class_names), activation='softmax')(x)
rice_model = keras.Model(inputs_rice, outputs_rice)

# 3. Compile the model
rice_model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# 4. Train the model on rice data only
print("\n--- Training the Rice Disease Model ---")
history_rice = rice_model.fit(
    rice_train_ds,
    validation_data=rice_val_ds,
    epochs=10
)

# 5. Save the specialized model
rice_model.save("rice_disease_model.keras")
print("\n✅ Rice model saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[62], line 4
#       1 RICE_DATA_DIR = "../data/rice_dataset"
#       3 # 1. Create the data loaders for the rice dataset
# ----> 4 rice_train_ds = tf.keras.utils.image_dataset_from_directory(
#       5     RICE_DATA_DIR,
#       6     validation_split=0.2,
#       7     subset="training",
#       8     seed=123,
#       9     image_size=IMAGE_SIZE,
#      10     batch_size=BATCH_SIZE
#      11 )
#      13 rice_val_ds = tf.keras.utils.image_dataset_from_directory(
#      14     RICE_DATA_DIR,
#      15     validation_split=0.2,
#    (...)     19     batch_size=BATCH_SIZE
#      20 )
#      22 rice_class_names = rice_train_ds.class_names
#
# File /opt/anaconda3/envs/disease_pred/lib/python3.12/site-packages/keras/src/utils/image_dataset_utils.py:232, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230 if seed is None:
#     231     seed = np.random.randint(1e6)
# --> 232 image_paths, labels, class_names = dataset_utils.index_directory(
#     233     directory,
#     234     labels,
#     235     formats=ALLOWLIST_FORMATS,
#     236     class_names=class_names,
#     237     shuffle=shuffle,
#     238     seed=seed,
#     239     follow_links=follow_links,
#     240     verbose=verbose,
#     241 )
#     243 if label_mode == "binary" and len(class_names) != 2:
#     244     raise ValueError(
#     245         'When passing `label_mode="binary"`, there must be exactly 2 '
#     246         f"class_names. Received: class_names={class_names}"
#     247     )
#
# File /opt/anaconda3/envs/disease_pred/lib/python3.12/site-packages/keras/src/utils/dataset_utils.py:530, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     528 if labels == "inferred":
#     529     subdirs = []
# --> 530     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     531         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     532             if not subdir.startswith("."):
#
# File /opt/anaconda3/envs/disease_pred/lib/python3.12/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)    765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory ../data/rice_dataset

# %%
# 1. Create a "model registry" to map crop names to their saved model files
model_registry = {
    "Tomato": {"path": "tomato_disease_model.keras", "classes": tomato_class_names},
    "Rice": {"path": "rice_disease_model.keras", "classes": rice_class_names}
}

# 2. Create a master prediction function
def predict_disease(crop_name, image_path):
    if crop_name not in model_registry:
        return f"Error: No model found for crop '{crop_name}'."
    
    # Load the correct model and class names from the registry
    model_info = model_registry[crop_name]
    model = keras.models.load_model(model_info["path"])
    class_names = model_info["classes"]
    
    # Load and preprocess the image
    img = keras.utils.load_img(image_path, target_size=IMAGE_SIZE)
    img_array = keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    # Make a prediction
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    
    # Return the predicted class and confidence
    predicted_class = class_names[np.argmax(score)]
    confidence = 100 * np.max(score)
    
    return f"This is a {crop_name} with {predicted_class} ({confidence:.2f}% confidence)."

# %%
'''
--- DEMONSTRATION ---
Assume you have a test image of a tomato
(You would replace this with a real image path)
test_tomato_image = "path/to/your/tomato.jpg" 
prediction = predict_disease("Tomato", test_tomato_image)
print(prediction)

Assume you have a test image of rice
test_rice_image = "path/to/your/rice.jpg"
prediction = predict_disease("Rice", test_rice_image)
print(prediction)
'''

# %%
# --- This would be a new cell in your notebook ---
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Let's evaluate the tomato model as an example
TOMATO_TEST_DIR = "datasets/tomato_dataset/test/"

# Create a test dataset
tomato_test_ds = tf.keras.utils.image_dataset_from_directory(
    TOMATO_TEST_DIR,
    shuffle=False, # Important: keep order for confusion matrix
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

# %%
# Evaluate the model
print("--- Evaluating Tomato Model ---")
loss, accuracy = tomato_model.evaluate(tomato_test_ds)
print(f"Test Accuracy: {accuracy*100:.2f}%")

# Create a confusion matrix
y_true = []
y_pred_probs = []
for images, labels in tomato_test_ds:
    y_true.extend(labels.numpy())
    y_pred_probs.extend(tomato_model.predict(images))

y_pred = np.argmax(y_pred_probs, axis=1)
cm = confusion_matrix(y_true, y_pred)
class_names = tomato_test_ds.class_names

# %%
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Tomato Model')
plt.show()

# %% [markdown]
# ## Model Refinement and Improvement
# How you'll likely want to improve your models.
#
# Fine-Tuning: Unfreeze the last few layers of the pre-trained base_model and retrain the whole model with a very low learning rate. This can significantly boost accuracy.
#
# Get More Data: If your model is confusing two diseases, it means you need more varied image examples of those specific conditions. More high-quality data is the single best way to improve performance.
